# %%
import re
from pdfplumber import open as pdf_open
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch

# Step 1: Extract text from PDF
def extract_text(pdf_path):
    with pdf_open(pdf_path) as pdf:
        text = ""
        for page in pdf.pages:
            text += page.extract_text()
    return text

# Step 2: Segment text into potential questions
def segment_questions(text):
    return re.split(r'\n\d+\.', text)  # Splits at numbered questions like "1."

# Step 3: Classify segments into question types
def classify_segments(segments):
    model_name = "bert-base-uncased"  # Load pre-trained or fine-tuned BERT
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=3)  # MCQ, Numerical, Other
    
    predictions = []
    for segment in segments:
        inputs = tokenizer(segment, return_tensors="pt", truncation=True, padding=True)
        outputs = model(**inputs)
        logits = outputs.logits
        label = torch.argmax(logits).item()
        predictions.append((segment, label))
    return predictions

# Step 4: Run the pipeline
pdf_path = "B:\PERSONAL DOCS\BUSSINESS MODEL\ONLINE EXAMINATION BUSINESS\CODE\PYTHON AI NLP PDF TO TEXT TO MCQ MODULE\CAT2000.pdf"
text = extract_text(pdf_path)
segments = segment_questions(text)
classified_segments = classify_segments(segments)

for segment, label in classified_segments:
    print(f"Segment: {segment[:50]}... | Label: {label}")
# Out:
# A:\Users\Lib\site-packages\transformers\utils\generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Segment: Bulls Eye
# 1
# www.hitbullseye.com CAT 2000
# SECTION I... | Label: 2
# Segment: ... | Label: 0
# Segment:  If caught in the act, they were punished, not for... | Label: 0
# Segment:  The bellicose Spartans sacrificed all the finer t... | Label: 0
# Segment:  Those fortunate enough to survive babyhood were t... | Label: 0
# Segment:  This consisted mainly of beatings and deprivation... | Label: 0
# Segment:  Male children were examined at birth by the city ... | Label: 0
# Segment:  BECDA 2. ECADB 3. BCDAE 4. ECDAB... | Label: 0
# Segment:
# A. This very insatiability of the photographing e... | Label: 0
# Segment:  EABCD 2. BDEAC 3. BCDAE 4. ECDAB... | Label: 0
# Segment:
# A. To be culturally literate is to possess the ba... | Label: 0
# Segment:  AECBD 2. DECBA 3. ACBED 4. DBCAEBulls Eye
# 2
# CAT 2... | Label: 0
# Segment:
# A. Both parties use capital and labour in the str... | Label: 0
# Segment:  ABCDE 2. CABDE 3. ACBED 4. CBEDA... | Label: 0
# Segment:
# A. The likelihood of an accident is determined by... | Label: 0
# Segment:  ABCD 2. ADCB 3. DBCA 4. DBAC
# DIRECTIONS for quest... | Label: 0
# Segment:  1. Security links exploit the same principle that... | Label: 0
# Segment:  Since the distance the rays travel changes with t... | Label: 0
# Segment:  ABCD 2. BADC 3. BDAC 4. DCAB... | Label: 0
# Segment:  1. Commercially reared chicken can be unusually a... | Label: 2
# Segment:  Bales could diminish aggressiveness and reduce in... | Label: 0
# Segment:  DCAB 2. CDBA 3. DBAC 4. BDCABulls Eye
# 3
# www.hitbu... | Label: 0
# Segment:  1. The concept of a ‘nation-state’ assumes a comp... | Label: 0
# Segment:  However the fiction has been and continues to be ... | Label: 0
# Segment:  DBAC 2. ABCD 3. BACD 4. DACB... | Label: 0
# Segment:  1. In the sciences, even questionable examples of... | Label: 0
# Segment:  Scientists funding data have no such defences.... | Label: 0
# Segment:  BDCA 2. ABDC 3. CABD 4. CDBA... | Label: 0
# Segment:  1. Horses and communism were, on the whole, a poo... | Label: 0
# Segment:  “A farmer’s pride is his horse; his cow may be th... | Label: 0
# Segment:  ACDB 2. DBCA 3. ABCD 4. DCBA
# DIRECTIONS: Read the... | Label: 0
# Segment:  In developing magnetic memory chips to replace th... | Label: 0
# Segment:  Volatile and non-volatile memories... | Label: 0
# Segment:  Magneto-resistance and magnetic tunnel-junctions.... | Label: 0
# Segment:  Radiation-disruption and radiation-neutral effect... | Label: 0
# Segment:  Orientation of magnetised spots on the surface of... | Label: 2
# Segment:  A binary digit or bit is represented in the magne... | Label: 0
# Segment:  A layer of aluminium oxide. 2. A capacitor... | Label: 0
# Segment:  A vertical pillar of magnetised material. 4. A ma... | Label: 0
# Segment:  In a magnetic tunnel-junctions (MTJs) tunnelling ... | Label: 0
# Segment:  Two magnetic layers are polarised in the same dir... | Label: 0
# Segment:  Two magnetic layers are polarised in the opposite... | Label: 0
# Segment:  Two aluminium-oxide barriers are polarised in the... | Label: 0
# Segment:  Two aluminium-oxide barriers are polarised in opp... | Label: 0
# Segment:  A major barrier on the way to build a full-scale ... | Label: 0
# Segment:  The low sensitivity of the magnetic memory elemen... | Label: 0
# Segment:  The thickness of aluminium oxide barriers.... | Label: 0
# Segment:  The need to develop more reliable and far smaller... | Label: 0
# Segment:  All the above... | Label: 0
# Segment:  In MTJs approach, it is possible to identify whet... | Label: 0
# Segment:  Measuring an element’s resistance and thus determ... | Label: 0
# Segment:  Measuring the degree of disruption caused by radi... | Label: 0
# Segment:  Magnetising the elements either clockwise or anti... | Label: 0
# Segment:  Measuring the current that flows through the sand... | Label: 0
# Segment:  A line of research which is trying to build a mag... | Label: 0
# Segment:  Paul Freitas.... | Label: 0
# Segment:  Stuart Parkin.... | Label: 0
# Segment:  Gary Prinz.... | Label: 0
# Segment:  None of the above.... | Label: 0
# Segment:  Experimental research currently underway, using r... | Label: 0
# Segment:  Working of a microprocessor.... | Label: 0
# Segment:  Working of a logic gate.... | Label: 0
# Segment:  Working of a magneto-resistance based chip.... | Label: 0
# Segment:  Working of a magneto tunnelling-junction(MTJ) bas... | Label: 0
# Segment:  From the passage, which of the following cannot b... | Label: 0
# Segment:  Electronic memory chips are faster and non-volati... | Label: 0
# Segment:  Electronic and magnetic storage technologies play... | Label: 0
# Segment:  MTJs are the more promising idea, compared to the... | Label: 0
# Segment:  non-volatile Electronics is the company set up to... | Label: 0
# Segment:  Which of the following best describes the approac... | Label: 0
# Segment:  Comparing experiences with two innovations tried,... | Label: 0
# Segment:  Presenting community perspectives on two technolo... | Label: 0
# Segment:  Using the negative outcomes of one innovation to ... | Label: 0
# Segment:  Contrasting two contexts separated in time, to il... | Label: 0
# Segment:  According to the passage, bereavement handling tr... | Label: 0
# Segment:  The community bereavement counsellors working wit... | Label: 0
# Segment:  The neighbours and kin joining the bereaved and m... | Label: 0
# Segment:  Using techniques developed systematically in form... | Label: 0
# Segment:  The Sauk Indian Chief leading the community with ... | Label: 0
# Segment:  Due to which of the following reasons, according ... | Label: 0
# Segment:  Over a period of time, working with Sauk Indians ... | Label: 0
# Segment:  She is working in an environment where the disapp... | Label: 0
# Segment:  Her efforts at grief processing with the bereaved... | Label: 0
# Segment:  She has been working with people who have settled... | Label: 0
# Segment:  According to the author, the bereavement counsell... | Label: 2
# Segment:  A friend of the bereaved helping him or her handl... | Label: 0
# Segment:  An advocate of the right to treatment for the com... | Label: 0
# Segment:  A kin of the bereaved helping him/her handle grie... | Label: 0
# Segment:  A formally trained person helping the bereaved ha... | Label: 0
# Segment:  The Prairie was a great puzzlement for the Europe... | Label: 0
# Segment:  It was covered with thick, untillable layers of g... | Label: 0
# Segment:  It was a large desert immediately next to lush fo... | Label: 0
# Segment:  It was rich cultivable land left fallow for centu... | Label: 0
# Segment:  It could be easily tilled with iron plows.... | Label: 0
# Segment:  Which of the following does the ‘desert’ in the p... | Label: 0
# Segment:  Prairie soil depleted by cultivation of wheat.... | Label: 0
# Segment:  Reservations in which native Indians were resettl... | Label: 0
# Segment:  Absence of, and emptiness in, community kinship a... | Label: 0
# Segment:  All of the above.Bulls Eye
# 9
# www.hitbullseye.com ... | Label: 0
# Segment:  According to the author, people will begin to uti... | Label: 0
# Segment:  New County regulations will make them feel it is ... | Label: 0
# Segment:  The bereaved in the community would find her a he... | Label: 0
# Segment:  She will fight for subsistence allowance from the... | Label: 0
# Segment:  Grief processing needs tools certified by univers... | Label: 0
# Segment:  Which one of the following parallels between the ... | Label: 0
# Segment:  Both are innovative technologies.... | Label: 0
# Segment:  Both result in migration of the communities into ... | Label: 0
# Segment:  Both lead to ‘deserts’ in the space of only one g... | Label: 0
# Segment:  Both are tools introduced by outsiders entering e... | Label: 0
# Segment:  The author’s contention that the notion of proper... | Label: 0
# Segment:  The creative output of a genius is invariably wri... | Label: 0
# Segment:  The link between the creator and his output is un... | Label: 0
# Segment:  The word “genius” is derived from a Latin word wh... | Label: 0
# Segment:  The music composer notates his music and thus bec... | Label: 0
# Segment:  Saussure’s conception of language as a communicat... | Label: 0
# Segment:  Teaching of North Indian classical music by word ... | Label: 0
# Segment:  Use of the recorded cassette as a transmission me... | Label: 0
# Segment:  Written down notation sheets of musical compositi... | Label: 0
# Segment:  Conductor’s baton and the orchestra.Bulls Eye
# 11
# ... | Label: 0
# Segment:  The author holds that the “rather ugly but benefi... | Label: 0
# Segment:  Storing the talas played upon the tabla, at vario... | Label: 0
# Segment:  Ensuring the continuance of a n ancient tradition... | Label: 0
# Segment:  Transporting North Indian classical music across ... | Label: 0
# Segment:  Capturing the transient moment of oral transmissi... | Label: 0
# Segment:  The oral transmission of North Indian classical m... | Label: 0
# Segment:  Efficacy of the guru-shishya tradition.... | Label: 0
# Segment:  Learning impact of direct demonstration.... | Label: 0
# Segment:  Brain’s ability to reproduce complex structures w... | Label: 0
# Segment:  The ability of an illiterate person to narrate gr... | Label: 0
# Segment:  According to the passage, in the North Indian cla... | Label: 0
# Segment:  Emphasises performance and invocation over the au... | Label: 0
# Segment:  Makes the music no one’s property.... | Label: 0
# Segment:  Values the composer more highly than the performe... | Label: 0
# Segment:  Supports oral transmission of traditional music.... | Label: 0
# Segment:  From the author’s explanation of the notion that ... | Label: 0
# Segment:  It is easy to transfer a piece of Western classic... | Label: 0
# Segment:  The conductor in the Western tradition, as a cust... | Label: 0
# Segment:  The authority of the Western classical music comp... | Label: 0
# Segment:  The power of the Western classical music composer... | Label: 0
# Segment:  According to the author, the inadequacy of teachi... | Label: 2
# Segment:  A loss of the structural beauty of the ragas.... | Label: 0
# Segment:  A fusion of two opposing approaches creating mund... | Label: 0
# Segment:  The conversion of free-flowing ragas into stilted... | Label: 0
# Segment:  Its failure to produce any noteworthy student or ... | Label: 0
# Segment:  Which of the following statements best conveys th... | Label: 0
# Segment:  North Indian and Western classical music are stru... | Label: 0
# Segment:  Western music is the intellectual property of the... | Label: 0
# Segment:  Creation as well as performance are important in ... | Label: 0
# Segment:  North Indian classical music is orally transmitte... | Label: 2
# Segment:  Which one of the following statements describes a... | Label: 0
# Segment:  The role of MNC s in the sphere of biotechnology ... | Label: 0
# Segment:  The strategy and policies for establishing an IPR... | Label: 0
# Segment:  The relative roles of public and private sectors.... | Label: 0
# Segment:  Wider concerns about ‘privatisation’ of research... | Label: 0
# Segment:  The fundamental breakthrough in deciphering the s... | Label: 0
# Segment:  Breakthroughs in fundamental research on DNA are ... | Label: 0
# Segment:  The fundamental research on DNA has the character... | Label: 0
# Segment:  Due to the large scale of fundamental research on... | Label: 0
# Segment:  The public and other companies must have free acc... | Label: 0
# Segment:  In debating the respective roles of the public an... | Label: 0
# Segment:  that private companies do not produce new varieti... | Label: 0
# Segment:  That almost all technological improvements are ba... | Label: 0
# Segment:  The complementary role of public and private sect... | Label: 0
# Segment:  The knowledge repositories are primarily the scie... | Label: 0
# Segment:  Which one of the following may provide incentives... | Label: 0
# Segment:  Include IPR issues in the TRIPs agreement.... | Label: 0
# Segment:  Nationalise MNCs engaged in private research in b... | Label: 0
# Segment:  Encourage domestic firms to patent their innovati... | Label: 0
# Segment:  Make provisions in the law for user compensation ... | Label: 0
# Segment:  Which of the following statements is not a not a ... | Label: 0
# Segment:  Development of newer and newer varieties will lea... | Label: 0
# Segment:  MNCs may underplay the negative consequences of t... | Label: 0
# Segment:  Newer varieties of seeds may increase vulnerabili... | Label: 0
# Segment:  Reforms in patent laws and user compensation agai... | Label: 0
# Segment:  The TRIPs agreement emerged from the Uruguay Roun... | Label: 0
# Segment:  Address the problem of adverse consequences of ge... | Label: 0
# Segment:  Fulfil the WTO requirement to have an agreement o... | Label: 0
# Segment:  Provide incentives to innovators by way of protec... | Label: 0
# Segment:  Give credibility to the innovations made by MNCs ... | Label: 0
# Segment:  Public or quasi-public research institutions are ... | Label: 0
# Segment:  Public research is not driven by profit motive.... | Label: 0
# Segment:  Private companies may not be able to absorb losse... | Label: 0
# Segment:  Unlike new technology products, knowledge and tec... | Label: 0
# Segment:  All of the above... | Label: 0
# Segment:  While developing a strategy and policies for buil... | Label: 0
# Segment:  Public and quasi-public institutions are not inte... | Label: 0
# Segment:  Public and quasi-public institutions have a broad... | Label: 0
# Segment:  Private companies are incapable of building produ... | Label: 0
# Segment:  Traditional and folk knowledge cannot be protecte... | Label: 0
# Segment:  According to the author, the introduction of abst... | Label: 0
# Segment:  Celebrated the hopes and aspirations of a newly i... | Label: 0
# Segment:  Provided a new direction to Indian art, towards s... | Label: 0
# Segment:  Managed to obtain internationalist support for th... | Label: 0
# Segment:  Was an emancipation from the dogmas of the nascen... | Label: 0
# Segment:  Which one of the following is not part of the aut... | Label: 0
# Segment:  An exploration of the subconscious mind.... | Label: 0
# Segment:  A lack of full commitment to non-representational... | Label: 0
# Segment:  An adherence to the symbolic while aspiring to th... | Label: 0
# Segment:  Usage of the images of Gods or similar symbols.... | Label: 0
# Segment:  Which one of the following, according to the auth... | Label: 0
# Segment:  Some artists have followed their abstractionist l... | Label: 0
# Segment:  Some artists have allowed chance or pattern to do... | Label: 0
# Segment:  Many artists have avoided the trap of a near-gene... | Label: 0
# Segment:  Many artists have found it difficult to fuse the ... | Label: 0
# Segment:  According to the author, the attraction of the Ka... | Label: 0
# Segment:  The conservative tendency to aspire to the mystic... | Label: 0
# Segment:  The discomfort of Indian abstractionists with Mal... | Label: 0
# Segment:  The easy identification of obvious points of affi... | Label: 0
# Segment:  The double-edged nature of abstractionism which e... | Label: 0
# Segment:  Which one of the following is not stated by the a... | Label: 0
# Segment:  Abstractionism has failed to reorient itself in t... | Label: 0
# Segment:  Abstractionism has not considered the development... | Label: 0
# Segment:  Abstractionism has not followed the path taken by... | Label: 0
# Segment:  The impact of mass media on viewers' expectations... | Label: 0
# Segment:  Given the author's delineation of the three abstr... | Label: 0
# Segment:  Depletion of nature's cyclical renewal.... | Label: 0
# Segment:  Use of non-representational images.... | Label: 0
# Segment:  Emphasis on arrangement of forms.... | Label: 0
# Segment:  Limited reliance on original models.... | Label: 0
# Segment:  Which one of the following, according to the auth... | Label: 0
# Segment:  It provides an idiom that can be understood by mo... | Label: 0
# Segment:  It highlights the absence of a shared language of... | Label: 0
# Segment:  It highlights the contradictory artistic trends o... | Label: 0
# Segment:  It helps abstractionists invoke the wistful, deli... | Label: 0
# Segment:  According to the author, which one of the followi... | Label: 0
# Segment:  Abstractionism appear to be unable to transcend t... | Label: 0
# Segment:  Abstractionism has allowed itself to be continued... | Label: 0
# Segment:  Abstractionism have been unable to use the multip... | Label: 0
# Segment:  All of aboveBulls Eye
# 18
# CAT 2000 www.hitbullseye... | Label: 0
# Segment:  It will take some time for many South Koreans to ... | Label: 0
# Segment:  Reconcile, decide 2. Understand, clarify... | Label: 0
# Segment:  Make out, decide 4. Reconcile, understand... | Label: 0
# Segment:  The law prohibits a person from felling a sandalw... | Label: 0
# Segment:  middlemen, rich 2. the government, poor 3. touts,... | Label: 0
# Segment:  The manners and ________ of the nouveau riche is ... | Label: 0
# Segment:  style, motif 2. morals, story 3. wealth, theme 4.... | Label: 0
# Segment:  In these bleak and depressing times of ________ p... | Label: 0
# Segment:  escalating, increasing 2. spiraling, booming... | Label: 0
# Segment:  spiraling, soaring 4. Ascending, debilitating... | Label: 0
# Segment:  Though one eye is kept firmly on the ________, th... | Label: 0
# Segment:  present, experimental 2. future, popular... | Label: 0
# Segment:  present, popular 4. market, popular
# End of Sectio... | Label: 0
# Segment:  The number of triangles with integral sides that ... | Label: 0
# Segment:  6 2. 5 3. 4 4. 3... | Label: 0
# Segment:  N = 1421  1423  1425. What is the remainder whe... | Label: 0
# Segment:  0 2. 9 3. 3 4. 6... | Label: 0
# Segment:  x is number of numbers between 100 and 200 such t... | Label: 0
# Segment:  16 2. 12 3. 11 4. 13... | Label: 0
# Segment:  Let S be the set of prime numbers greater than or... | Label: 0
# Segment:  1 2. 4 3. 5 4. 10... | Label: 0
# Segment:  The integers 34,041 and 32,506 when divided by a ... | Label: 0
# Segment:  289 2. 367 3. 453 4. 307... | Label: 0
# Segment:  Let x, y and z be distinct integers, that are odd... | Label: 0
# Segment:  xyz2 is odd 2. (x – y)2 z is even... | Label: 0
# Segment:  (x + y – z) 2 (x + y) is even 4. (x - y) (y + 2) ... | Label: 0
# Segment:  Sam has forgotten his friend’s seven-digit teleph... | Label: 0
# Segment:  10,000 2. 2430 3. 3402 4. 3006... | Label: 0
# Segment:  There are two positive integers – x and y. A func... | Label: 0
# Segment:  2 2. 4 3. 3 4. Cannot be determined... | Label: 0
# Segment:  The number 1982 in the decimal system when writte... | Label: 0
# Segment:  1182 2. 1912 3. 1192 4. 1292Bulls Eye
# 20
# CAT 2000... | Label: 0
# Segment:  A farmer has decided to build a wire fence along ... | Label: 0
# Segment:  100, 15 2. 100, 16 3. 120, 15 4. 120, 16... | Label: 0
# Segment:  Two full tanks, one shaped like a cylinder and th... | Label: 0
# Segment:  700 2. 1000 3. 1100 4. 1200... | Label: 0
# Segment:  A shipping clerk has five boxes of different but ... | Label: 0
# Segment:  60 kg 2. 62 kg 3. 64 kg 4. Can’t be determined... | Label: 0
# Segment:  A truck travelling at 70 km/h consumes 30% more f... | Label: 0
# Segment:  130 2. 140 3. 150 4. 175... | Label: 0
# Segment:  What is the value of the following expression?
# 1 ... | Label: 0
# Segment:  9/19 2. 10/19 3. 10/21 4. 11/21... | Label: 0
# Segment:  If x > 2 and y > -1, then which of the following ... | Label: 0
# Segment:  xy >-2 2. –x < 2y 3. xy < -2 4. –x > 2y... | Label: 0
# Segment:  One red, three white and two blue flags are arran... | Label: 0
# Segment:  6 2. 4 3. 10 4. 2... | Label: 0
# Segment:  Two variables x and y are defined such that for t... | Label: 0
# Segment:  y = a + bx 2. y = a + bx + cx2 3. y = e a + bx 4.... | Label: 0
# Segment:  A series is defined such that a = 1, a = 2a + 5, ... | Label: 0
# Segment:  5  299 + 6 2. 5  299 - 6 3. 6  299 + 5 4. 6  ... | Label: 0
# Segment:  D is a recurring decimal of type 0. a a a a a a a... | Label: 0
# Segment:  18 2. 108 3. 198 4. 288... | Label: 0
# Segment:  There are seven consecutive integers. The average... | Label: 0
# Segment:  n 2. n + 1... | Label: 0
# Segment:  kn, here k is a function of n 4. n + 2/7... | Label: 0
# Segment:  ABCD is a rhombus with AC and BD intersecting on ... | Label: 0
# Segment:  x + y = 1 2. x + y = -1 3. x – y = 1 4. x – y = -... | Label: 0
# Segment:  What is the area bounded by the curves | x + y | ... | Label: 0
# Segment:  4 2.3 3. 2 4. 1... | Label: 0
# Segment:  x and y are defined such that x2 + y2 = 0.1 If | ... | Label: 0
# Segment:  0.3 2. 0.4 3. 0.2 4. 0.6... | Label: 0
# Segment:  Referring to the diagram below, if AB = BC = CD =... | Label: 0
# Segment:  150 2. 200 3. 300 4. 250... | Label: 0
# Segment:  If x3- ax2+ bx- a = 0 has 3 real roots then,... | Label: 0
# Segment:  b = 1 2. b  1 3. a = 1 4. a  1... | Label: 0
# Segment:  The expression N = 553 + 173 – 723 is exactly div... | Label: 0
# Segment:  7 & 13 2. 3 & 13 3. 17 & 7 4. 3 &17... | Label: 0
# Segment:  A circle of radius 1 has 7 sectors S1, S2, … S7, ... | Label: 0
# Segment:   /508 2.  / 2040 3.  /1016 4.  / 1524Bulls Ey... | Label: 0
# Segment:  The three sides of a triangle have lengths a, b, ... | Label: 0
# Segment:  equilateral 2. isosceles 3. right angled 4. obtus... | Label: 0
# Segment:  There are two disjointed sets S and S where –
# 1 2... | Label: 0
# Segment:  0 2. 1 3. 2 4. Can’t be determined... | Label: 0
# Segment:  ABCDEFGH is a regular octagon. A and E are opposi... | Label: 0
# Segment:  Zero 2. Four 3. 2n – 1 4. Can’t be determined... | Label: 0
# Segment:  There are three cities A, B and C. Each of these ... | Label: 0
# Segment:  6 2. 3 3. 5 4. 10
# DIRECTIONS for questions 87 – 8... | Label: 2
# Segment:  The sum of A & B is given by... | Label: 0
# Segment:  \ (@ (A, B), 2) 2. @ (\(A, B),2)... | Label: 0
# Segment:  @ (X (A, B) 2) 4. None of these... | Label: 0
# Segment:  The average of A, B & C is given by... | Label: 0
# Segment:  @(x ( \ (@ ( A, B ), 2 ), C), 3) 2. \ (x ( \ (@ (... | Label: 0
# Segment:  x (@ ( \ (@ (A, B), 2) C, 3) 4. @ ( \ (@ (A,B), 2... | Label: 0
# Segment:  What is the value of product, f(2) f2 (2) f 3(2) ... | Label: 0
# Segment:  1/3 2. 3 3. 1/18 4. None of these... | Label: 0
# Segment:  If r is an integer  2, then what is the value of... | Label: 0
# Segment:  -1 2. 0 3. 1 4. None of these
# DIRECTIONS for ques... | Label: 0
# Segment:  If f (x) = 3f (-x)... | Label: 0
# Segment:  If f (x) = f (-x)... | Label: 0
# Segment:  If f (x) = - f (- x)... | Label: 0
# Segment:  If 3f ( x ) = 6 f (- x)... | Label: 0
# Segment: ... | Label: 0
# Segment: ... | Label: 0
# Segment: Bulls Eye
# 24
# CAT 2000 www.hitbullseye.com
# DIRECTIO... | Label: 2
# Segment:  Which of the following is necessarily greater tha... | Label: 0
# Segment:  (h(x, y, z)- f(x, y, z)) /j(x, y, z)... | Label: 0
# Segment:  j(x, y, z)/h(x, y, z)... | Label: 0
# Segment:  f(x, y, z)/g(x, y, z)... | Label: 0
# Segment:  f(x, y, z) + h(x, y, z) - g(x, y, z))/j(x, y, z)... | Label: 2
# Segment:  Which of the following expressions is necessarily... | Label: 0
# Segment:  (f(x, y, z)-m(x, y, z))/(g(x, y, z)-n(x, y, z))... | Label: 2
# Segment:  (m(x, y, z)-f(x, y, z))/(g(x, y, z)-n(x, y, z))... | Label: 2
# Segment:  (j(x, y, z)-g(x, y, z))/h(x, y, z)... | Label: 0
# Segment:  (f(x, y, z)-h(x, y, z))/f(x, y, z)... | Label: 0
# Segment:  Which of the following expressions is indetermina... | Label: 0
# Segment:  (f(x, y, z) - h(x, y, z)) / (g(x, y, z) - j(x, y,... | Label: 2
# Segment:  (f(x, y, z) + h(x, y, z) + g(x, y, z) + j(x, y, z... | Label: 2
# Segment:  (g(x, y, z) - f(x, y, z)) / (f(x, y, z) - h(x, y,... | Label: 0
# Segment:  (h(x, y, z) - f(x, y, z)) / (n(x, y, z) - g(x, y,... | Label: 2
# Segment:  If a function f(x) satisfies the equation fx ... | Label: 0
# Segment:  x2 – 2 for x 0 2. x2 – 2 for all satisfying |x| ... | Label: 0
# Segment:  x2 – 2 for all satisfying |x| < 2 4. None of thes... | Label: 0
# Segment:  Let n be the number of different 5 digit numbers,... | Label: 0
# Segment:  144 2.168 3. 192 4. None of these
# DIRECTIONS for ... | Label: 2
# Segment:  What is the total number of matches played in the... | Label: 0
# Segment:  28 2. 55 3. 63 4. 35... | Label: 0
# Segment:  The minimum number of wins needed for a team in t... | Label: 0
# Segment:  5 2. 6 3. 7 4. 4... | Label: 0
# Segment:  What is the highest number of wins for a team in ... | Label: 0
# Segment:  1 2. 2 3. 3 4. 4... | Label: 0
# Segment:  What is the number of rounds in the second stage ... | Label: 0
# Segment:  1 2. 2 3. 3 4. 4... | Label: 0
# Segment:  Which of the following statements is true?... | Label: 0
# Segment:  The winner will have more wins than any other tea... | Label: 0
# Segment:  At the end of the first stage, no team eliminated... | Label: 0
# Segment:  It is possible that the winner will have the same... | Label: 0
# Segment:  The number of team with exactly one win in the se... | Label: 2
# Segment:  After executing a sequence of these instructions,... | Label: 2
# Segment:  The second instruction is FILL (B, A).... | Label: 0
# Segment:  The second instruction is EMPTY (C,B).... | Label: 0
# Segment:  The second instruction transfers water from B to ... | Label: 0
# Segment:  The second instruction involves using the water i... | Label: 0
# Segment:  Consider the same sequence of three instructions ... | Label: 2
# Segment:  1 2. 2 3. 0 4. None of the above
# DIRECTIONS for q... | Label: 2
# Segment:  Which expression yields positive values for non z... | Label: 0
# Segment:  f(x,y) - g(x,y) 2. f(x,y) – [g(x,y)] 2 3. g(x,y) ... | Label: 0
# Segment:  When is f(x,y) > g(x,y)?... | Label: 0
# Segment:  y  x 2. Both x & y are less than –1... | Label: 0
# Segment:  Both x & y are greater than 0 4. Both x & y are l... | Label: 0
# Segment:  Each of the numbers x , x , ......x , n 4, is eq... | Label: 0
# Segment:  n is even 2. n is odd... | Label: 0
# Segment:  n is an odd multiple of 3 4. n is prime... | Label: 0
# Segment:  The table below shows the age-wise distribution o... | Label: 0
# Segment:  82.8 2. 90.8 3. 80.0 4. 90.0Bulls Eye
# 27
# www.hitb... | Label: 0
# Segment:  There is a vertical stack of books marked 1, 2 an... | Label: 0
# Segment:  1 2. 2 3. 3 4. 4
# End of Section IIBulls Eye
# 28
# CA... | Label: 2
# Segment:  In a triangle PQR, PRQ = 90 degrees. What is PR +... | Label: 0
# Segment:  Two concentric circles have the same centre O. A ... | Label: 2
# Segment:  What are the ages of X and Y?
# A. The difference i... | Label: 1
# Segment:  x is a real number. Is | x | < 3?
# A. x (x+3)<0
# B.... | Label: 0
# Segment:  a  b = 1 if a, b > 0 or a, b < 0
# a  b = - 1 oth... | Label: 0
# Segment:  Harshad bought shares of a certain company on one... | Label: 0
# Segment:  How many people watch program P?
# A. The number wa... | Label: 0
# Segment:  Two lines are given by the equations, ax + by = c... | Label: 0
# Segment:  Ghosh flies to South Africa from Mumbai non stop.... | Label: 0
# Segment:  Is z the smallest of x, y, z?
# A. x is greater tha... | Label: 0
# Segment:  The country with the largest %age change in FEI i... | Label: 2
# Segment:  India 2. China 3. Malaysia 4. Thailand... | Label: 0
# Segment:  Based on the data provided, it can be concluded t... | Label: 0
# Segment:  Absolute value of foreign equity inflows in 1998 ... | Label: 0
# Segment:  Absolute value of foreign equity inflows was high... | Label: 0
# Segment:  Absolute value of foreign equity inflows was lowe... | Label: 0
# Segment:  None of the above can be inferred.Bulls Eye
# 30
# CA... | Label: 0
# Segment:  It is known that China’s GDP in 1998 was 7% highe... | Label: 0
# Segment:  I, III &IV 2. II, III & IV 3. I, III & V 4. II & ... | Label: 0
# Segment:  China’s foreign equity inflows in 1998 were 10 ti... | Label: 0
# Segment:  China’s GDP in 1998 was 40% higher than that of I... | Label: 0
# Segment:  China’s GDP in 1998 was 70% higher than that of I... | Label: 0
# Segment:  China’s GDP in 1998 was 50% higher than that of I... | Label: 0
# Segment:  No inference can be drawn about relative magnitud... | Label: 0
# Segment:  Which is the sector with the highest growth durin... | Label: 0
# Segment:  Manufacturing 2. Mining and quarrying 3. Electric... | Label: 0
# Segment:  The overall growth rate in 1991 of the four secto... | Label: 0
# Segment:  10% 2. 1% 3. 2.5% 4. 1.5%... | Label: 2
# Segment:  When was the highest level of production in the m... | Label: 0
# Segment:  1998 2. 1995 3. 1990 4. None of these... | Label: 0
# Segment:  When was the lowest level of production of the mi... | Label: 0
# Segment:  1996 2. 1993 3. 1990 4. None of these... | Label: 0
# Segment:  The percentage increase of production in four sec... | Label: 0
# Segment:  25 2. 20 3. 50 4. 40... | Label: 0
# Segment:  It is known that the index of total industrial pr... | Label: 0
# Segment:  Then, the percentage increase in production betwe... | Label: 0
# Segment:  57.5 2. 87.5 3. 127.5 4. 47.5
# DIRECTIONS for ques... | Label: 0
# Segment:  The highest growth rate in deficit intensity was ... | Label: 0
# Segment:  95 2. 96 3. 97 4. 98Bulls Eye
# 32
# CAT 2000 www.hit... | Label: 0
# Segment:  Referring to the previous question, the percentag... | Label: 2
# Segment:  8.45% 2. 2.15% 3. 33.3% 4. 23.5%... | Label: 1
# Segment:  In 98 total cost of Raw Material was approximatel... | Label: 0
# Segment:  3.3 2. 4.3 3. 0.33 4. Can’t be determined... | Label: 0
# Segment:  Which of the following statements is true?... | Label: 0
# Segment:  Between 94 & 98, exports increase every year.... | Label: 0
# Segment:  Between 94 & 98 imports decreased every year.... | Label: 0
# Segment:  The deficit intensity in 98 was less than that in... | Label: 0
# Segment:  The deficit intensity increased every year betwee... | Label: 2
# Segment:  In recent report, the gross enrollment ratios at ... | Label: 0
# Segment:  The definition of gross enrolment ratio does not ... | Label: 0
# Segment:  A school attendance study found that many childre... | Label: 0
# Segment:  A study estimated that close to 22 percent of chi... | Label: 0
# Segment:  Demographic surveys show shifts in the population... | Label: 0
# Segment:  Although in the limited sense of freedom regardin... | Label: 2
# Segment:  A decision of the chairman of the Central Bank to... | Label: 0
# Segment:  Government has repeatedly resorted to monetisatio... | Label: 0
# Segment:  The Central Bank does not need the central govern... | Label: 0
# Segment:  The inability to remove coin shortage was a major... | Label: 0
# Segment:  About 96% of Scandinavian moths have ears tuned t... | Label: 0
# Segment:  A higher proportion of deaf moths than hearing mo... | Label: 0
# Segment:  Deaf moths may try to avoid bats by frequent chan... | Label: 0
# Segment:  Deaf moths are faster than hearing moths, and so ... | Label: 0
# Segment:  The large wingspan enables deaf moths to better r... | Label: 0
# Segment:  Szymanski suggests that the problem of racism in ... | Label: 0
# Segment:  Certain clubs took advantage of the situation by ... | Label: 0
# Segment:  Clubs hired white players at relatively high wage... | Label: 0
# Segment:  During the study period, clubs in towns with a hi... | Label: 0
# Segment:  Clubs in one region, which had higher proportions... | Label: 0
# Segment:  The offer of the government to make iodised salt ... | Label: 2
# Segment:  The government proposes to save on costs by using... | Label: 0
# Segment:  The chain of fair-price distribution outlets now ... | Label: 0
# Segment:  Many small-scale and joint-sector units have comp... | Label: 0
# Segment:  The government which initiated the earlier effort... | Label: 0
# Segment:  The problem of traffic congestion in Athens has b... | Label: 2
# Segment:  In the 1980s, many families purchased second cars... | Label: 0
# Segment:  In the mid-1990s, many families found it feasible... | Label: 0
# Segment:  Post-1993, many families seized the opportunity t... | Label: 0
# Segment:  All of the above.... | Label: 0
# Segment:  The pressure on Italy's 257 jails has been increa... | Label: 0
# Segment:  Opinion polls have indicated that many Italians f... | Label: 0
# Segment:  The opposition may be persuaded to help since amn... | Label: 0
# Segment:  During a recent visit to a large prison, the Pope... | Label: 0
# Segment:  Shortly before the recommendation was made, 58 pr... | Label: 0
# Segment:  The Shveta-chattra or the "White Umbrella" was a ... | Label: 2
# Segment:  The placing of an umbrella over the ruler's head ... | Label: 2
# Segment:  The white umbrella represented the instrument of ... | Label: 0
# Segment:  The umbrella, not necessarily a white one, was a ... | Label: 0
# Segment:  The varied use of the umbrella symbolised the com... | Label: 0
# Segment:  The theory of games is suggested to some extent b... | Label: 0
# Segment:  The team of Tenzing Norgay and Edmund Hillary cli... | Label: 0
# Segment:  A national level essay writing competition.... | Label: 0
# Segment:  A decisive war between the armed forces of India ... | Label: 0
# Segment:  Oil Exporters' Union deciding on world oil prices... | Label: 0
# Segment:  Argentina's beef cattle herd has dropped to under... | Label: 0
# Segment:  The animals are worth less, too: prices fell by o... | Label: 0
# Segment:  There has been a change in consumer preference to... | Label: 0
# Segment:  Prices of imported beef have been increasing, thu... | Label: 0
# Segment:  The inability to cross breed native cattle with i... | Label: 0
# Segment:  Animal rights pressure groups have come up rapidl... | Label: 0
# Segment:  The total annual exports lay between 35 and 40 pe... | Label: 0
# Segment:  97-98 & 2. 96-97 & 97-98 3. 96-97 & 4. 96-97 & 94... | Label: 0
# Segment:  The highest percentage growth in the total IT bus... | Label: 0
# Segment:  95-96 2. 96-97 3. 97-98 4. 98-99... | Label: 0
# Segment:  Which of the following statements is correct?... | Label: 0
# Segment:  The annual software exports steadily increased bu... | Label: 0
# Segment:  The annual peripheral exports steadily increased ... | Label: 0
# Segment:  The IT business in training during 1994-1999 was ... | Label: 0
# Segment:  None of the above statements is true.
# Additional ... | Label: 0
# Segment:  For the IT hardware business activity which one o... | Label: 0
# Segment:  1997-98 dominates 1996-97... | Label: 0
# Segment:  1997-98 dominates 1995-96... | Label: 0
# Segment:  1995-98 dominates 1998-99... | Label: 0
# Segment:  1998-99 dominates 1996-97... | Label: 0
# Segment:  For the two It business activities hardware and p... | Label: 0
# Segment:  1996-97 dominates 1995-96... | Label: 0
# Segment:  1998-99 dominates 1995-96... | Label: 0
# Segment:  1997-98 dominates 1998-99... | Label: 0
# Segment:  None of the theseBulls Eye
# 37
# www.hitbullseye.com... | Label: 0
# Segment:  If the overall average employment per factory was... | Label: 0
# Segment:  43 2. 47 3. 50 4. 54... | Label: 0
# Segment:  The Value Added per employee is highest in... | Label: 0
# Segment:  Central PSU 2. C & S PSU 3. Joint Sector 4. Priva... | Label: 0
# Segment:  Capital productivity ( = gross output per Rupee o... | Label: 0
# Segment:  Joint, private, C & S... | Label: 0
# Segment:  Private, joint , C & S... | Label: 0
# Segment:  Private , C & S, Joint... | Label: 0
# Segment:  Joint, Private, Central... | Label: 0
# Segment:  A sector is defined as “Pareto efficient” if its ... | Label: 0
# Segment:  Wholly private 2. Joint... | Label: 0
# Segment:  Central and State/Local 4. Others... | Label: 0
# Segment:  Total Value Added in all sectors in the economy w... | Label: 0
# Segment:  141 2. 14.1 3. 131 4. 13.1Bulls Eye
# 38
# CAT 2000 w... | Label: 0
# Segment:  Total production in July is 40 units. what is the... | Label: 0
# Segment:  3600 2. 90 3. 140 4. 115... | Label: 0
# Segment:  ABC Ltd. is considering increasing the production... | Label: 0
# Segment:  110 2. 140 3. 150 4. 160... | Label: 0
# Segment:  From the data provided it can be inferred that, f... | Label: 0
# Segment:  MC is an increasing function of production quanti... | Label: 0
# Segment:  MC is a decreasing function of production quantit... | Label: 0
# Segment:  Initially MC is a decreasing function of producti... | Label: 0
# Segment:  None of the above... | Label: 0
# Segment:  Suppose that each widget sells for Rs. 150. What ... | Label: 0
# Segment:  2400 2. 1600 3. 400 4. 0... | Label: 0
# Segment:  Assume that the unit price is Rs. 150 and profit ... | Label: 0
# Segment:  30 2. 50 3. 60 4. 40... | Label: 0
# Segment:  For monthly production level in the rage of 0 to ... | Label: 0
# Segment:  AC is always higher than MC... | Label: 0
# Segment:  AC is always lower than MC... | Label: 0
# Segment:  AC is lower than MC up to a certain level and the... | Label: 0
# Segment:  None of the above is true.Bulls Eye
# 39
# www.hitbul... | Label: 0
# Segment:  Persons X, Y, Z and Q live in red, green, yellow ... | Label: 0
# Segment:  Blue 2. Green... | Label: 0
# Segment:  Red 4. Not possible to determine... | Label: 0
# Segment:  Five persons with names P, M, U, T and X live sep... | Label: 0
# Segment:  Hut 2. Palace 3. Fort 4. House... | Label: 0
# Segment:  Harry’s bag can carry at most 10 books. Harry mus... | Label: 0
# Segment:  20 2. 21 3. 22 4. 23... | Label: 0
# Segment:  Eighty kilograms of store material is to be trans... | Label: 0
# Segment:  Rs. 180 2. Rs. 160 3. Rs. 140 4. Rs. 120... | Label: 0
# Segment:  In a certain zoo, animals are kept in enclosures.... | Label: 2
# Segment:  Bison and Bear 2. Bison and Deer... | Label: 0
# Segment:  Bear and Lion 4. Bear and Panther
# End of Section ... | Label: 0
# Segment:  1 41. 4 81. 4 121. 1 161. 1... | Label: 0
# Segment:  3 42. 2 82. 3 122. 4 162. 2... | Label: 0
# Segment:  1 43. 2 83. 1 123. 4 163. 1... | Label: 0
# Segment:  2 44. 1 84. 2 124. 3 164. 2... | Label: 0
# Segment:  4 45. 4 85. 1 125. 3 165. 1... | Label: 0
# Segment:  2 46. 1 86. 2 126. 4... | Label: 0
# Segment:  4 47. 3 87. 1 127. 1... | Label: 0
# Segment:  1 48. 3 88. 4 128. 2... | Label: 0
# Segment:  3 49. 2 89. 3 129. 1... | Label: 0
# Segment:  3 50. 4 90. 2 130. 2... | Label: 0
# Segment:  2 51. 1 91. 2 131. 1... | Label: 0
# Segment:  3 52. 4 92. 3 132. 4... | Label: 0
# Segment:  1 53. 1 93. 3 133. 2... | Label: 0
# Segment:  3 54. 3 94. 4 134. 4... | Label: 0
# Segment:  4 55. 2 95. 2 135. 3... | Label: 0
# Segment:  4 56. 3 96. 2 136. 2... | Label: 0
# Segment:  2 57. 3 97. 2 137. 2... | Label: 0
# Segment:  1 58. 4 98. 3 138. 2... | Label: 0
# Segment:  3 59. 1 99. 3 139. 3... | Label: 0
# Segment:  2 60. 4 100. 2 140. 4... | Label: 0
# Segment:  3 61. 4 101. 1 141. 4... | Label: 0
# Segment:  4 62. 3 102. 3 142. 4... | Label: 0
# Segment:  1 63. 2 103. 3 143. 3... | Label: 0
# Segment:  4 64. 3 104. 2 144. 1... | Label: 0
# Segment:  1 65. 4 105. 3 145. 2... | Label: 0
# Segment:  2 66. 4 106. 4 146. 1... | Label: 0
# Segment:  3 67. 2 107. 2 147. 3... | Label: 0
# Segment:  1 68. 3 108. 1 148. 4... | Label: 0
# Segment:  4 69. 3 109. 2 149. 4... | Label: 0
# Segment:  3 70. 2 110. 4 150. 1... | Label: 0
# Segment:  1 71. 1 111. 2 151. 2... | Label: 0
# Segment:  2 72. 2 112. 2 152. 2... | Label: 0
# Segment:  4 73. 4 113. 4 153. 3... | Label: 0
# Segment:  2 74. 3 114. 1 154. 4... | Label: 0
# Segment:  2 75. 2 115. 3 155. 3... | Label: 0
# Segment:  1 76. 2 116. 1 156. 2... | Label: 0
# Segment:  3 77. 2 117. 3 157. 4... | Label: 0
# Segment:  4 78. 2 118. 4 158. 3... | Label: 0
# Segment:  1 79. 4 119. 4 159. 1... | Label: 0
# Segment:  3 80. 2 120. 3 160. 4Bulls Eye
# 41
# www.hitbullseye... | Label: 0
# Segment:  A comparison is done of two systems of music,
# hen... | Label: 0
# Segment:  The debate is about building a dynamic national
# E... | Label: 0
# Segment:  By definition, a public good is something that ca... | Label: 0
# Segment:  The paragraph must start with B and followed by E... | Label: 0
# Segment:  The passage states that both public and private
# a... | Label: 0
# Segment:  B introduces the subject and must be followed by ... | Label: 0
# Segment:  A introduces the subject “culturally literate” 39... | Label: 0
# Segment:  The introduction is social cost followed by “both... | Label: 0
# Segment:  The best introduction is “simplest strategic 41. ... | Label: 0
# Segment:  It is stated that public and quasi-public institu... | Label: 0
# Segment:  B is the logical sequel to changing colours
# have ... | Label: 0
# Segment:  Third paragraph: “it led art towards the explorat... | Label: 0
# Segment:  “Low light must follow “darkened sheds” hence
# of ... | Label: 0
# Segment:  Same as above – it was not part of the conservati... | Label: 0
# Segment:  D introduces a contrary idea and there is a direc... | Label: 0
# Segment:  It is stated that some artists have taken it to t... | Label: 0
# Segment:  The logical sequence to fraud is suspicion in C
# o... | Label: 0
# Segment:  Middle of the passage – points of affinity with t... | Label: 0
# Segment:  After the first sentence, we must describe horses... | Label: 0
# Segment:  The passage says, “Like all solutions…” hence we... | Label: 0
# Segment:  Directly stated in the second paragraph.
# infer (3... | Label: 0
# Segment:  Third paragraph, second line. politics or art.... | Label: 0
# Segment:  Stated in third last paragraph, second line.... | Label: 0
# Segment:  “the idiom is based on the lyric play of forms…”... | Label: 0
# Segment:  Stated in third last paragraph, “according to Pau... | Label: 0
# Segment:  “By measuring the current that flows through the... | Label: 0
# Segment:  All the choices are stated in the passage.
# sandwi... | Label: 0
# Segment:  Note that they are all working on different aspec... | Label: 0
# Segment:  Directly stated in the fourth paragraph. reconcil... | Label: 0
# Segment:  The first statement is not stated in the passage.... | Label: 0
# Segment:  The author is clearly comparing two innovations. ... | Label: 0
# Segment:  Traditionally, neighbours provide solace to the 5... | Label: 0
# Segment:  Directly stated in the last paragraph. 54. The be... | Label: 0
# Segment:  “a formally trained person armed with a diploma r... | Label: 0
# Segment:  First paragraph. popular art is promoted.... | Label: 0
# Segment:  All the given choices re directly stated in the 5... | Label: 0
# Segment:  It is stated the county regulations require makin... | Label: 0
# Segment:  The innovations do not lead to migration of 57. N... | Label: 0
# Segment:  Third last paragraph: the author explains the not... | Label: 0
# Segment:  First paragraph: the tradition of guru and shishy... | Label: 0
# Segment:  The cassette does not serve the purpose of captur... | Label: 0
# Segment:  The tradition is stated to be oral – hence it doe... | Label: 0
# Segment:  The question asks why the raga remains greater th... | Label: 0
# Segment:  The music does not lie mute but is written down i... | Label: 0
# Segment:  According to the passage, Indian classical music
# ... | Label: 0
# Segment:  Focus on only the last four digits. For the numbe... | Label: 0
# Segment:  f (0,2) = 2 + 1 = 3 79. Triangle ABC is isosceles... | Label: 0
# Segment:  1982 in base 12 will be If we look at the 3 angle... | Label: 0
# Segment:  Let x be number of posts. But that angle and the ... | Label: 0
# Segment:  Let c be cone vol. We know for sure that the seco... | Label: 0
# Segment:  Heaviest + second heaviest = 121 kg, = 72[17*(55 ... | Label: 0
# Segment:  Here the number of jumps required will always be... | Label: 0
# Segment:  Distance travelled = (19.5100) / (13010) even (... | Label: 0
# Segment:  The given equation can be re written as always be... | Label: 0
# Segment:  Since x > 2, -x < -2 and since y > -1, 2y > -2.
# I... | Label: 0
# Segment:  There can be 6 possible arrangements odd number o... | Label: 0
# Segment:  The data is not linear. So check (b).
# Let the equ... | Label: 0
# Segment:  a can be written as (6 20 – 5). the options and ... | Label: 0
# Segment:  D = 0.a1a2a1a2…………= (a1a2) / 99, the equations wi... | Label: 0
# Segment:  Let the numbers be A, A+1, A+2, … therefore 88. F... | Label: 0
# Segment:  Diagonals intersect at right angles, so rhombus i... | Label: 2
# Segment:  We can generalise , fn(-x) = n - x. 101 We can ha... | Label: 0
# Segment:  These problems can be solved by referring to the ... | Label: 0
# Segment:  Here the tables are – leads to 2 litres more bein... | Label: 0
# Segment:  Here the tables are must be in both B and C.
# x: -... | Label: 2
# Segment:  Since the numbers are distinct, none of them are ... | Label: 0
# Segment:  Same as above. 1. Entire lot from A – B.... | Label: 0
# Segment:  Same as above. 2. Both 2-3 from B - A... | Label: 0
# Segment:  f  x1 x  x2 x1 2 f  x1 x    x... | Label: 0
# Segment:  The rule for divisibility by 4 is that the last t... | Label: 0
# Segment:  28 + 28 in round robin, 7 in next rounds. 117 Bot... | Label: 2
# Segment: 99. For China it is 4.8-5.96=-1.16. 1991 it become... | Label: 2
# Segment: 71... | Label: 0
# Segment: 5 and for chemical it is 19.5. The total comes to
# ... | Label: 0
# Segment: 67
# increase.
# For Thailand, change is 14.34%
# 130 Si... | Label: 0
# Segment: 74% respectively.
# Now total weightage for manufact... | Label: 0
# Segment: 72102x to 1997-98 are 5.1, 6.3, 7.6, and 5.
# For 1... | Label: 2
# Segment: 66.3
# 107y
# 4.85.136y.And FEI in
# rate... | Label: 0
# Segment: 3
# 10023.5%
# 100
# 133 From the tables given,
# 1997=5... | Label: 0
# Segment: 72 and hence, unrepresentative, thus resulting in
# ... | Label: 0
# Segment: 8
# concerned with demographic trends, but only with... | Label: 0
# Segment: 8-0.218=21.582. Similarly, for mining and
# intentio... | Label: 0
# Segment: 582+15.75+11.88+16.21=65.42. Now 65.42-
# 140 (a) wo... | Label: 0
# Segment: 35=1.07 which comes to approximately 1.5%Bulls Eye... | Label: 0
# Segment: 3
# number of cars and congestion.
# 141 Only (d) conn... | Label: 0
# Segment: 903 3
# marginal political factors. (a), (b) and (... | Label: 0
# Segment:  The minimum cost comes in the case of 10 kg
# × 8, ... | Label: 2
